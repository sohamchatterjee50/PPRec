# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
from src.utils import DATA_FOLDER
from src.data.split import EBNeRDSplit
import os

# %%
# set the env var or change this
data_folder = DATA_FOLDER or "data"
print(data_folder)

if not os.path.exists(data_folder):
    raise ValueError(f"Data folder {data_folder} does not exist")
# Out:
# /Users/pepijnvanderklei/Data/RecSys

# %%
predictions_txt_path = os.path.join(data_folder, 'predictions.txt')
articles_parquet_path = os.path.join(data_folder, 'articles.parquet')

# %% [markdown]
# # Predictions
#
# This is an example of the file we have to submit to the challenge. So in the test set, there is a behaviors file which does include the articles view column, but does not contain the articles clicked column. The goal is submit a ranking of all the articles viewed, by chance of clicking. So just the ranking of the viewed articles based on the output of our model.

# %%
predictions = pd.read_csv(predictions_txt_path, sep=' ', header=None)
predictions.columns = ['impression_id', 'rankings']

# %% [markdown]
# # Articles
#
# These top level articles are **all** the articles I presume? The separate data folders `demo`, `small` and `large` all have an articles file as well.

# %%
articles = pd.read_parquet(articles_parquet_path)
print(articles.columns)
print(articles)
# Out:
# Index(['article_id', 'title', 'subtitle', 'last_modified_time', 'premium',
#        'body', 'published_time', 'image_ids', 'article_type', 'url',
#        'ner_clusters', 'entity_groups', 'topics', 'category', 'subcategory',
#        'category_str', 'total_inviews', 'total_pageviews', 'total_read_time',
#        'sentiment_score', 'sentiment_label'],
#       dtype='object')
#         article_id                                              title  \
# 0          3000022                     Hanks beskyldt for mishandling
# 1          3000063                    Bostrups aske spredt i Furesøen
# 2          3000613                Jesper Olsen ramt af hjerneblødning
# 3          3000700                           Madonna topløs med heste
# 4          3000840                            Otto Brandenburg er død
# ...            ...                                                ...
# 125536     9803505                Flyvende Antonsen knuser topspiller
# 125537     9803510  Nedschroef Langeskov udbetalte udbytte på toci...
# 125538     9803525   Dansk skuespiller: - Jeg nægtede, at jeg var syg
# 125539     9803560        Så slemt er det: 14.000 huse er oversvømmet
# 125540     9803607        Aktion mod svindlere: Seks personer anholdt
#
#                                                  subtitle  last_modified_time  \
# 0       Tom Hanks har angiveligt mishandlet sin afdøde... 2023-06-29 06:20:32
# 1            Studieværten blev mindet med glad festlighed 2023-06-29 06:20:32
# 2       Den tidligere danske landsholdsspiller i fodbo... 2023-06-29 06:20:33
# 3       47-årige Madonna poserer både topløs og sammen... 2023-06-29 06:20:33
# 4       Sangeren og skuespilleren Otto Brandenburg er ... 2023-06-29 06:20:33
# ...                                                   ...                 ...
# 125536  Verdens nummer syv, Chou Tien-Chen, fik ikke e... 2023-06-29 06:49:26
# 125537  Hos Nedschroef Langeskov ApS udbetalte man i d... 2023-06-29 06:49:26
# 125538  Julie R. Ølgaard fik akut kejsersnit og fødte ... 2023-06-29 06:49:26
# 125539  Tusindvis af huse står under vand i Kherson-re... 2023-06-29 06:49:26
# 125540  Flere kvinder er ifølge politiet blevet svindl... 2023-06-29 06:49:26
#
#         premium                                               body  \
# 0         False  Tom Hanks skulle angiveligt have mishandlet si...
# 1         False  Strålende sensommersol. Jazzede toner. Glas me...
# 2         False  Jesper Olsen, der er noteret for 43 kampe på d...
# 3         False  Skal du have stillet Madonna-sulten inden konc...
# 4         False  'Og lidt for Susanne, Birgitte og Hanne... ' '...
# ...         ...                                                ...
# 125536    False  Anders Antonsen har holdt pause fra badmintonb...
# 125537    False  Et udbytte på 30 millioner kroner blev i sidst...
# 125538    False  Mens hun lå søvnløs, lød kakofonien fra baggår...
# 125539    False  Et område på omkring 600 kvadratkilometer står...
# 125540    False  Mindst otte personer er blevet anholdt og sigt...
#
#             published_time                                          image_ids  \
# 0      2006-09-20 09:24:18                                          [3518381]
# 1      2006-09-24 07:45:30                                 [3170935, 3170939]
# 2      2006-05-09 11:29:00                                          [3164998]
# 3      2006-05-04 11:03:12                                          [3172046]
# 4      2007-03-01 18:34:00                                          [3914446]
# ...                    ...                                                ...
# 125536 2023-06-08 05:54:06                                          [9803516]
# 125537 2023-06-08 05:48:51                                          [9803509]
# 125538 2023-06-08 06:45:46  [9803518, 9803519, 9803520, 9803521, 9803522, ...
# 125539 2023-06-08 06:25:42                                               None
# 125540 2023-06-08 06:54:53                                          [9803906]
#
#            article_type                                                url  \
# 0       article_default  https://ekstrabladet.dk/underholdning/udlandke...
# 1       article_default  https://ekstrabladet.dk/nyheder/samfund/articl...
# 2       article_default  https://ekstrabladet.dk/sport/fodbold/landshol...
# 3       article_default  https://ekstrabladet.dk/underholdning/udlandke...
# 4       article_default  https://ekstrabladet.dk/nyheder/samfund/articl...
# ...                 ...                                                ...
# 125536  article_default  https://ekstrabladet.dk/sport/anden_sport/badm...
# 125537  article_default  https://ekstrabladet.dk/auto/magna/regnskaber/...
# 125538  article_default  https://ekstrabladet.dk/underholdning/dkkendte...
# 125539  article_default  https://ekstrabladet.dk/nyheder/saa-slemt-er-d...
# 125540  article_default  https://ekstrabladet.dk/krimi/aktion-mod-svind...
#
#         ...                                      entity_groups  \
# 0       ...                                              [PER]
# 1       ...                                                 []
# 2       ...                               [LOC, PER, PER, PER]
# 3       ...                                                 []
# 4       ...                                                 []
# ...     ...                                                ...
# 125536  ...  [PER, PROD, PER, PER, MISC, MISC, PER, PER, LO...
# 125537  ...                     [LOC, ORG, LOC, LOC, ORG, PER]
# 125538  ...              [PER, PROD, PER, PER, PER, PER, MISC]
# 125539  ...     [LOC, LOC, LOC, PROD, PER, LOC, ORG, ORG, LOC]
# 125540  ...  [PER, PER, PER, LOC, ORG, LOC, LOC, PER, PER, ...
#
#                                                    topics category  \
# 0       [Kriminalitet, Kendt, Underholdning, Personfar...      414
# 1       [Kendt, Underholdning, Begivenhed, Personlig b...      118
# 2       [Kendt, Sport, Fodbold, Sundhed, Sygdom og beh...      142
# 3                        [Kendt, Livsstil, Underholdning]      414
# 4       [Kendt, Underholdning, Begivenhed, Personlig b...      118
# ...                                                   ...      ...
# 125536  [Kendt, Begivenhed, Sport, Ketcher- og batspor...      142
# 125537              [Erhverv, Privat virksomhed, Økonomi]     2889
# 125538  [Kendt, Livsstil, Familieliv, Underholdning, F...      414
# 125539  [International politik, Katastrofe, Større kat...      118
# 125540                          [Kriminalitet, Bedrageri]      140
#
#          subcategory   category_str total_inviews  total_pageviews  \
# 0              [432]  underholdning           NaN              NaN
# 1              [133]        nyheder           NaN              NaN
# 2         [196, 271]          sport           NaN              NaN
# 3              [432]  underholdning           NaN              NaN
# 4              [133]        nyheder           NaN              NaN
# ...              ...            ...           ...              ...
# 125536    [327, 330]          sport       13320.0            959.0
# 125537  [2890, 2900]           auto          12.0              1.0
# 125538         [425]  underholdning      315391.0          50361.0
# 125539            []        nyheder       21318.0           1237.0
# 125540            []          krimi      331057.0          79590.0
#
#         total_read_time  sentiment_score  sentiment_label
# 0                   NaN           0.9911         Negative
# 1                   NaN           0.5155          Neutral
# 2                   NaN           0.9876         Negative
# 3                   NaN           0.8786          Neutral
# 4                   NaN           0.9468         Negative
# ...                 ...              ...              ...
# 125536          55691.0           0.8884         Positive
# 125537             25.0           0.8723         Negative
# 125538        2550671.0           0.7737         Negative
# 125539          67514.0           0.9927         Negative
# 125540        3694760.0           0.9948         Negative
#
# [125541 rows x 21 columns]

# %% [markdown]
# # Data Splits
#
# Info can be found here: https://recsys.eb.dk/dataset/
#
# ---
#
# ## Articles
#
# This speaks for itself. All articles with an id, title, body, catagory etc.
#
# ---
#
# ## Behaviours / Impressions
#
# Every behaviour (i.e. impression), is some time where a user has seen a list of articles. I'll note the difference between the article, inview articles and clicked articles, since it was a bit unclear what article id was to me.
#
# ### Article Id
#
# This is article from where the impression was made. So lets say this is Youtube. When viewing a video, there is a list of recommended videos on the right. This 'article id' would be the video that was watched. The 'impression' would be the list of recommended videos. This can be None if the user is not already watching a video (so reading an article for us), but is on the homepage for example.
#
# ### Inview Article Ids
#
# These are actually the articles id's of the recommended news articles (so the recommended videos in the case of Youtube).
#
# ### Clicked Article Ids
#
# These are the videos that were clicked from the list. These could be multiple, since some user might click a video, then go back and click another one.
#
# ---
#
# ## History
#
# This is just a simplifief version of the behaviours file, where user id is the main key, contains all the articles ever clicked by a user. So we can use this to find the input data to the Popularity-aware User Encoder, in a easier and cleaner way than the behaviours file.
#
# ---

# %% [markdown]
# ## Demo

# %%
demo_train_split = EBNeRDSplit('train', "demo")
demo_train_split.summarize(show_columns=True)
demo_train_split._history.head()
# Out:
# Articles: (11777, 21)
# Columns Articles:  Index(['article_id', 'title', 'subtitle', 'last_modified_time', 'premium',
#        'body', 'published_time', 'image_ids', 'article_type', 'url',
#        'ner_clusters', 'entity_groups', 'topics', 'category', 'subcategory',
#        'category_str', 'total_inviews', 'total_pageviews', 'total_read_time',
#        'sentiment_score', 'sentiment_label'],
#       dtype='object')
#
#
# Behaviors: (24724, 17)
# Columns Behaviors:  Index(['impression_id', 'article_id', 'impression_time', 'read_time',
#        'scroll_percentage', 'device_type', 'article_ids_inview',
#        'article_ids_clicked', 'user_id', 'is_sso_user', 'gender', 'postcode',
#        'age', 'is_subscriber', 'session_id', 'next_read_time',
#        'next_scroll_percentage'],
#       dtype='object')
#
#
# History: (1590, 5)
# Columns History:  Index(['user_id', 'impression_time_fixed', 'scroll_percentage_fixed',
#        'article_id_fixed', 'read_time_fixed'],
#       dtype='object')
#          user_id                              impression_time_fixed  \
# user_id
# 13538      13538  [2023-04-27T10:17:43.000000, 2023-04-27T10:18:...
# 58608      58608  [2023-04-27T18:48:09.000000, 2023-04-27T18:48:...
# 95507      95507  [2023-04-27T15:20:28.000000, 2023-04-27T15:20:...
# 106588    106588  [2023-04-27T08:29:09.000000, 2023-04-27T08:29:...
# 617963    617963  [2023-04-27T14:42:25.000000, 2023-04-27T14:43:...
#
#                                    scroll_percentage_fixed  \
# user_id
# 13538    [100.0, 35.0, 100.0, 24.0, 100.0, 23.0, 100.0,...
# 58608    [37.0, 61.0, 100.0, 100.0, 55.0, 100.0, 100.0,...
# 95507    [60.0, 100.0, 100.0, 21.0, 29.0, 67.0, 49.0, 5...
# 106588   [24.0, 57.0, 100.0, nan, nan, 100.0, 100.0, 73...
# 617963   [100.0, 100.0, nan, 46.0, 23.0, 19.0, 61.0, 70...
#
#                                           article_id_fixed  \
# user_id
# 13538    [9738663, 9738569, 9738663, 9738490, 9738663, ...
# 58608    [9739362, 9739179, 9738567, 9739344, 9739202, ...
# 95507    [9739035, 9738646, 9634967, 9738902, 9735495, ...
# 106588   [9738292, 9738216, 9737266, 9737556, 9737657, ...
# 617963   [9739035, 9739088, 9738902, 9738968, 9738760, ...
#
#                                            read_time_fixed
# user_id
# 13538    [17.0, 12.0, 4.0, 5.0, 4.0, 9.0, 5.0, 46.0, 11...
# 58608    [2.0, 24.0, 72.0, 65.0, 11.0, 4.0, 101.0, 0.0,...
# 95507    [18.0, 29.0, 51.0, 12.0, 10.0, 10.0, 13.0, 24....
# 106588   [9.0, 15.0, 42.0, 9.0, 3.0, 58.0, 26.0, 214.0,...
# 617963   [45.0, 29.0, 116.0, 26.0, 34.0, 42.0, 58.0, 59...

# %%
demo_train_split._articles.sample(10)
# Out:
#             article_id                                              title  \
# article_id
# 9744693        9744693  Restaurant på Nørrebro skifter sur smiley ud m...
# 9330229        9330229  Uhyggelige videoer: Riffelmand truer med selvmord
# 9747633        9747633    Danske Mike i Ukraine: - En helvedes masse vold
# 9737393        9737393   Kønsskiftet voldtægtsdømt vil afsone med kvinder
# 9737071        9737071        Efter bizart pressemøde: Nu trækker hun sig
# 9486486        9486486                Prostatalægen: Sådan lever jeg selv
# 8189648        8189648               Melina: Endnu en debutant på toppen!
# 9751866        9751866                     Alvorlige anklager mod Rusland
# 8423084        8423084      Kærlighedseksperten guider: Sådan dater du nu
# 8054212        8054212                       Henriette elsker sex i bilen
#
#                                                      subtitle  \
# article_id
# 9744693     Restauranten Falafel Factory på Nørrebro kan n...
# 9330229     Fire videoklip viste før og under de dødbringe...
# 9747633     Bykamp er den mest ekstreme form for krig. Dan...
# 9737393     62-årig tidligere mand, der afsoner forvaring ...
# 9737071     Den engelske tennisspiller Emma Raducanu trækk...
# 9486486     Prostatakræft er den mest hyppige kræftsygdom ...
# 8189648     Melina, 24 år og fra Helsingør: Wow! Det er je...
# 9751866     Ukraine har frigivet optagelser, der angivelig...
# 8423084     Hvordan bærer man sig ad, hvis man som single ...
# 8054212     Kæresteparret Lars og Henriette ynder at dyrke...
#
#             last_modified_time  premium  \
# article_id
# 9744693    2023-06-29 06:48:29    False
# 9330229    2023-06-29 06:42:30     True
# 9747633    2023-08-25 12:44:47     True
# 9737393    2023-06-29 06:48:21     True
# 9737071    2023-06-29 06:48:21    False
# 9486486    2023-06-29 06:44:45     True
# 8189648    2023-06-29 06:30:54     True
# 9751866    2023-06-29 06:48:36    False
# 8423084    2023-06-29 06:33:58     True
# 8054212    2023-07-31 12:54:04     True
#
#                                                          body  \
# article_id
# 9744693     En sur smiley kan nu rives ned og en glad hæng...
# 9330229     Fire korte videoklip lagt ud på Youtube af den...
# 9747633     Lyskeglen fra lommelygten på Mikes våben strej...
# 9737393     En 62-årig, der biologisk er mand, men juridis...
# 9737071     WTA-turneringen Madrid Open bliver en stjerne ...
# 9486486     Klinisk professor og overlæge i urinvejskirurg...
# 8189648     Se minigalleriet med Melina i bunden af artikl...
# 9751866     Den brutale kamp om Bakhmut fortsætter.\nSiden...
# 8423084     Det er ikke let at være på jagt efter kærlighe...
# 8054212     Kæresteparret Lars og Henriette er begge del a...
#
#                 published_time  \
# article_id
# 9744693    2023-05-01 15:01:41
# 9330229    2022-07-08 05:05:32
# 9747633    2023-05-07 08:28:24
# 9737393    2023-04-27 12:26:16
# 9737071    2023-04-26 11:37:23
# 9486486    2023-01-05 06:05:07
# 8189648    2020-07-04 21:30:00
# 9751866    2023-05-06 14:49:44
# 8423084    2021-01-24 20:04:44
# 8054212    2020-04-25 18:55:11
#
#                                                     image_ids  \
# article_id
# 9744693                                             [9744692]
# 9330229                           [9330323, 9330736, 9328690]
# 9747633         [9749125, 9638628, 9749121, 9647422, 9749122]
# 9737393                           [9737397, 9737395, 7673550]
# 9737071                                    [9736208, 9737088]
# 9486486                                             [9486502]
# 8189648         [8178743, 8178744, 8178742, 8178745, 8178743]
# 9751866                                             [9744934]
# 8423084         [8423320, 8423321, 8423306, 8427168, 8423319]
# 8054212     [8066573, 8066582, 8066571, 8066580, 8066574, ...
#
#                article_type  \
# article_id
# 9744693     article_default
# 9330229     article_default
# 9747633     article_default
# 9737393     article_default
# 9737071     article_default
# 9486486     article_default
# 8189648     article_default
# 9751866     article_default
# 8423084     article_default
# 8054212     article_default
#
#                                                           url  ...  \
# article_id                                                     ...
# 9744693     https://ekstrabladet.dk/auto/magna/smileys/res...  ...
# 9330229     https://ekstrabladet.dk/krimi/uhyggelige-video...  ...
# 9747633     https://ekstrabladet.dk/krimi/danske-mike-i-uk...  ...
# 9737393     https://ekstrabladet.dk/krimi/koensskiftet-vol...  ...
# 9737071     https://ekstrabladet.dk/sport/anden_sport/tenn...  ...
# 9486486     https://ekstrabladet.dk/forbrug/sundhed/prosta...  ...
# 8189648     https://ekstrabladet.dk/side9/maanedens/melina...  ...
# 9751866     https://ekstrabladet.dk/nyheder/krigogkatastro...  ...
# 8423084     https://ekstrabladet.dk/sex_og_samliv/kaerligh...  ...
# 8054212     https://ekstrabladet.dk/sex_og_samliv/henriett...  ...
#
#                                                 entity_groups  \
# article_id
# 9744693                             [ORG, ORG, LOC, LOC, LOC]
# 9330229                 [ORG, ORG, ORG, LOC, PROD, PER, PROD]
# 9747633     [LOC, ORG, ORG, ORG, PER, PER, ORG, MISC, MISC...
# 9737393                   [ORG, LOC, ORG, PER, ORG, ORG, ORG]
# 9737071                    [PER, EVENT, ORG, EVENT, PER, ORG]
# 9486486                                 [LOC, PER, LOC, MISC]
# 8189648                                                    []
# 9751866     [LOC, LOC, PER, ORG, PER, LOC, ORG, ORG, PER, ...
# 8423084                                                    []
# 8054212                        [LOC, ORG, ORG, ORG, LOC, LOC]
#
#                                                        topics category  \
# article_id
# 9744693     [Erhverv, Privat virksomhed, Livsstil, Kultur,...     2889
# 9330229             [Kriminalitet, Personfarlig kriminalitet]      140
# 9747633                   [Konflikt og krig, Væbnet konflikt]      140
# 9737393             [Kriminalitet, Personfarlig kriminalitet]      140
# 9737071     [Kendt, Begivenhed, Sport, Sundhed, Sygdom og ...      142
# 9486486     [Livsstil, Samfund, Sundhed, Sygdom og behandl...      457
# 8189648                                    [Livsstil, Erotik]      572
# 9751866                   [Konflikt og krig, Væbnet konflikt]      118
# 8423084                               [Livsstil, Partnerskab]      565
# 8054212              [Livsstil, Transportmiddel, Bil, Erotik]      565
#
#              subcategory   category_str total_inviews  total_pageviews  \
# article_id
# 9744693     [2890, 2901]           auto         10417               31
# 9330229               []          krimi          <NA>             <NA>
# 9747633               []          krimi       1116167            40164
# 9737393               []          krimi       1307006           141959
# 9737071       [327, 349]          sport        539855           104596
# 9486486            [475]        forbrug          <NA>             <NA>
# 8189648            [573]          side9          <NA>             <NA>
# 9751866            [127]        nyheder        585474           117934
# 8423084               []  sex_og_samliv          <NA>             <NA>
# 8054212               []  sex_og_samliv          <NA>             <NA>
#
#             total_read_time  sentiment_score  sentiment_label
# article_id
# 9744693                 650           0.8632         Positive
# 9330229                <NA>           0.9944         Negative
# 9747633             2976915           0.9101         Negative
# 9737393             7435040           0.8861         Negative
# 9737071             4689783           0.9341         Negative
# 9486486                <NA>           0.8432          Neutral
# 8189648                <NA>           0.9770         Positive
# 9751866             9505974           0.9933         Negative
# 8423084                <NA>           0.8660          Neutral
# 8054212                <NA>           0.8792          Neutral
#
# [10 rows x 21 columns]

# %% [markdown]
# ## Small

# %%
small_train_split = EBNeRDSplit('train', "small")
print(len(small_train_split._behaviors))
small_train_split._behaviors.tail()
# Out:
# 232887
#                impression_id  article_id     impression_time  read_time  \
# impression_id
# 580099643          580099643     9769306 2023-05-18 10:01:05      121.0
# 580099644          580099644     9770882 2023-05-18 10:05:07      176.0
# 580099645          580099645     9769306 2023-05-18 10:11:03       24.0
# 580100695          580100695     9771242 2023-05-18 10:00:08        5.0
# 580100697          580100697     9771242 2023-05-18 10:01:29       14.0
#
#                scroll_percentage  device_type  \
# impression_id
# 580099643                  100.0            3
# 580099644                  100.0            3
# 580099645                  100.0            3
# 580100695                  100.0            1
# 580100697                  100.0            1
#
#                                               article_ids_inview  \
# impression_id
# 580099643      [9233208, 9771242, 9767697, 9514481, 9771065, ...
# 580099644      [9771065, 9767697, 9770886, 9758882, 9709817, ...
# 580099645      [9771042, 9440508, 9486080, 9770997, 9120051, ...
# 580100695      [9440508, 9142581, 9769917, 9767697, 9514481, ...
# 580100697      [9233208, 8422665, 9769306, 9771042, 9514481, ...
#
#               article_ids_clicked  user_id  is_sso_user  gender  postcode  \
# impression_id
# 580099643               [9770886]  2106715        False    <NA>      <NA>
# 580099644               [9769306]  2106715        False    <NA>      <NA>
# 580099645               [9771042]  2106715        False    <NA>      <NA>
# 580100695               [9767697]  2110744        False    <NA>      <NA>
# 580100697               [9771042]  2110744        False    <NA>      <NA>
#
#                 age  is_subscriber  session_id  next_read_time  \
# impression_id
# 580099643      <NA>          False     1416293             121
# 580099644      <NA>          False     1416293             148
# 580099645      <NA>          False     1416293               4
# 580100695      <NA>          False      747086              75
# 580100697      <NA>          False      747086             123
#
#                next_scroll_percentage
# impression_id
# 580099643                         NaN
# 580099644                       100.0
# 580099645                         NaN
# 580100695                       100.0
# 580100697                        25.0

# %% [markdown]
# # Artifacts
#
# There is some files with outputs for standart embedding models, for all the articles. So for models like BERT, RoBERTa, Word2Vec, and some Contrastive model. The word2vec model is not a word to embbeding mapping, but article to embedding mapping. I its a sum of all the embeddings of the words in the article.
#
# ## We can't really use this
#
# But our model needs a word2vec model which actually maps words to embeddings.
#
# > Given a news title, we obtain the word em- beddings based on word embedding dictionary pre- trained on large-scale corpus to incorporate initial word-level semantic information. We also convert entities into embeddings based on pre-trained entity embeddings to incorporate knowledge information in knowledge graphs to our model.
#
# They do not really state which dictionary they use I think. So lets find it in their code, or we can just choose and download a word2vec model. Lets find something Huggingface for this. Then we have two options. We can use the word2vec model as a dictionary, like the autors do, or arguably better, train it together with our model!
#
# ## But we can use it as a starting point
#
# Songga said a good first step is to not implement the Knowledge-aware News Encoder right away. This model takes in an article and outputs some embeddings. So she said we can start using this.

# %%
bert_parquet_path = os.path.join(data_folder, "google_bert_base_multilingual_cased", 'bert_base_multilingual_cased.parquet')
roberta_parquet_path = os.path.join(data_folder, "FacebookAI_xlm_roberta_base", 'xlm_roberta_base.parquet')
word2vec_parquet_path = os.path.join(data_folder, "Ekstra_Bladet_word2vec", 'document_vector.parquet')
contrastive_parquet_path = os.path.join(data_folder, "Ekstra_Bladet_contrastive_vector", 'contrastive_vector.parquet')

# %%
bert_parquet = pd.read_parquet(bert_parquet_path)
roberta_parquet = pd.read_parquet(roberta_parquet_path)
word2vec_parquet = pd.read_parquet(word2vec_parquet_path)
contrastive_parquet = pd.read_parquet(contrastive_parquet_path)

# %%
print(bert_parquet['google-bert/bert-base-multilingual-cased'].iloc[0].shape)
print(type(bert_parquet['google-bert/bert-base-multilingual-cased'].iloc[0]))
bert_parquet.head()
# Out:
# (768,)
# <class 'numpy.ndarray'>
#    article_id           google-bert/bert-base-multilingual-cased
# 0     3000022  [-0.35060593, 0.0034366532, -0.1756858, -0.088...
# 1     3000063  [-0.0034481985, 0.22765873, -0.19700234, 0.060...
# 2     3000613  [-0.03811903, -0.030120859, -0.6928362, 0.0801...
# 3     3000700  [-0.29374197, -0.07282147, -0.0926456, -0.0540...
# 4     3000840  [0.0019190352, -0.010633812, -0.49158585, 0.17...

# %%
print(roberta_parquet['FacebookAI/xlm-roberta-base'].iloc[0].shape)
print(type(roberta_parquet['FacebookAI/xlm-roberta-base'].iloc[0]))
roberta_parquet.head()
# Out:
# (768,)
# <class 'numpy.ndarray'>
#    article_id                        FacebookAI/xlm-roberta-base
# 0     3000022  [0.102449246, 0.10114823, 0.056887403, 0.02293...
# 1     3000063  [0.10729711, 0.103072755, 0.054031033, -0.0292...
# 2     3000613  [0.12513922, 0.12462065, 0.061414186, -0.03694...
# 3     3000700  [0.10569707, 0.07633519, 0.0717533, 0.00109790...
# 4     3000840  [0.098174535, 0.114628576, 0.03703187, -0.0088...

# %%
print(word2vec_parquet['document_vector'].iloc[0].shape)
print(type(word2vec_parquet['document_vector'].iloc[0]))
word2vec_parquet.head()
# Out:
# (300,)
# <class 'numpy.ndarray'>
#    article_id                                    document_vector
# 0     3000022  [0.06542388, -0.047424573, 0.06384871, -0.0014...
# 1     3000063  [0.028815078, -0.00016637295, 0.055056807, 0.0...
# 2     3000613  [0.037971217, 0.03392251, 0.027297212, 0.01708...
# 3     3000700  [0.04652399, 0.0029133065, 0.06280604, -0.0051...
# 4     3000840  [0.014736942, 0.024067875, 0.0051865038, 0.041...

# %%
print(contrastive_parquet['contrastive_vector'].iloc[0].shape)
print(type(contrastive_parquet['contrastive_vector'].iloc[0]))
contrastive_parquet.head()
# Out:
# (768,)
# <class 'numpy.ndarray'>
#    article_id                                 contrastive_vector
# 0     3000022  [-0.012159083, 0.057096627, 0.018299146, -0.03...
# 1     3000063  [0.03448151, 0.033532683, 0.054597735, -0.0231...
# 2     3000613  [-0.01463833, 0.030934403, 0.036162928, 0.0394...
# 3     3000700  [-0.06416679, 0.004852634, 0.0132708335, -0.00...
# 4     3000840  [-0.01304012, 0.024513246, 0.031050924, 0.0123...
